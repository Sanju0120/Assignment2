# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <br> __SANJEEV TEJA P__ <br>
# <br> Current Ocuupation : Working as a Senior Systems Engineer in Infosys Limited <br>
# <br> Desired Occupation : To work as a Data Engineer in a reputed company. <br>

# %% [markdown]
# <br> __My Interest in Data Science__ <br>
# <br> _I am interested in Data Science as it gives me a creative freedom to visualize and predict/analyse any situation by the data obtained from the previous/ongoing instances_ <br>

# %% [markdown]
# ### Code to append new elements into an existing list

# %%
# Define a list of numbers
list1 = [2,4,6,8,10]

print ("Old list = ", list1)

# Append another element into the list

list1.append(12)

print("List after append = ", list1)
# Out:
# Old list =  [2, 4, 6, 8, 10]
# List after append =  [2, 4, 6, 8, 10, 12]

# %% [markdown]
# ![Welcome to Juypter](https://3s81si1s5ygj3mzby34dq6qf-wpengine.netdna-ssl.com/wp-content/uploads/2021/02/Jupyter_main.png)
# #### The below steps are algorithm of the above code
#  - Define a list of n numbers of any datatype
#  - Enter the new element that needs to be appended into the list
#   1. Make sure to keep the new element of same datatype as the elements in the list
#   2. Please print the element if possible.
#  - Use the append command to add the element into existing list
#   1. The appending element can be a single element or a list of elements
#   2. Make sure to keep the name of appending list different from the original list
#  - Print the appended list
